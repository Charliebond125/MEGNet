# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/vlawhern/arl-eegmodels.git
# Out:
# Cloning into 'arl-eegmodels'...
# remote: Enumerating objects: 112, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 112 (delta 1), reused 4 (delta 1), pack-reused 106
# Receiving objects: 100% (112/112), 80.61 KiB | 2.12 MiB/s, done.
# Resolving deltas: 100% (48/48), done.

# %%
# !pip install mne
# Out:
# Requirement already satisfied: mne in /usr/local/lib/python3.10/dist-packages (1.4.2)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from mne) (1.22.4)
# Requirement already satisfied: scipy>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from mne) (1.10.1)
# Requirement already satisfied: matplotlib>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from mne) (3.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mne) (4.65.0)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.10/dist-packages (from mne) (1.6.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mne) (23.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from mne) (3.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->mne) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->mne) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->mne) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->mne) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->mne) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->mne) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->mne) (2.8.2)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (2.27.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->mne) (2.1.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.4.0->mne) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4)

# %%
import numpy as np
import pandas as pd
import mne
from mne import read_epochs
from mne import pick_types, Epochs
from mne.channels import read_layout
from tensorflow.keras.utils import to_categorical
from sklearn.utils import shuffle
from sklearn.metrics import roc_auc_score, accuracy_score, f1_score
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import backend as K
K.set_image_data_format('channels_last')
import sys, os

# os.rename('/content/arl-eegmodels', '/content/arl_eegmodels')

from arl_eegmodels.EEGModels import EEGNet, ShallowConvNet, DeepConvNet

# %%
# Function to preprocess the data for a specific event pair
def preprocess_data(event_pair_function, epochs_data):
    epochs_data_selected = event_pair_function(epochs_data)

    # Select only gradiometer channels
    grad_channels = mne.pick_types(epochs_data_selected.info, meg='grad')
    grad_channel_names = [epochs_data_selected.ch_names[ch] for ch in grad_channels]
    epochs_data_selected = epochs_data_selected.pick_channels(grad_channel_names)

    return epochs_data_selected

# Your provided functions for each event pair
def hands_vs_feet(epochs_data):
    event_dict = [
        "hand_imagery",
        "feet_imagery"
    ]

    return epochs_data[event_dict]


def hands_vs_word(epochs_data):
    event_dict = [
        "hand_imagery",
        "word_imagery"
    ]

    return epochs_data[event_dict]

def hands_vs_sub(epochs_data):
    event_dict = [
        "hand_imagery",
        "subtraction_imagery"
    ]


    return epochs_data[event_dict]

def feet_vs_word(epochs_data):
    event_dict = [
        "feet_imagery",
        "word_imagery"
    ]

    return epochs_data[event_dict]

def feet_vs_sub(epochs_data):
    event_dict = [
        "feet_imagery",
        "subtraction_imagery"
    ]

    return epochs_data[event_dict]

def word_vs_sub(epochs_data):
    event_dict = [
        "word_imagery",
        "subtraction_imagery"
    ]

    return epochs_data[event_dict]

def min_max_scaler(epoch_data):
    # scales data to -1, 1
    max_abs = np.max(np.abs(epoch_data))
    processed_data = epoch_data / max_abs
    return processed_data

def mne_standard_scaler(epoch_data):
    # Different from sklearn standardscaler
    # Works via channel to channel

    from mne.decoding import Scaler
    scaler = Scaler(scalings="mean")
    scaled_data = scaler.fit_transform(epoch_data)
    return scaled_data

def z_score_scaler(epoch_data):
    # scales by removing mean and unit standard deviation
    mean = np.mean(epoch_data)
    std = np.std(epoch_data)
    processed_data = (epoch_data - mean) / std
    return processed_data

# %% [markdown]
# <h1> Using LOOCV for entire epoched dataset with combined runs. <h1>

# %%
# Subject 3

n_epochs = 20

out_f_name = '/content/drive/MyDrive/MEG' +'acc_EEGNet' + '_epochs_' + str(n_epochs) + '_filtered_' + 'sub_7.npy'
print(out_f_name)

# (loading dataset)
print("Loading epoched data...")
epoched_data = mne.read_epochs('/content/drive/MyDrive/MEG/Maxwell Filtered Data/Combined Run data/Sub_3_combined_epochs-epo.fif', preload=True)
print(f"Epoched data successfully loaded {epoched_data}")
# Out:
# /content/drive/MyDrive/MEGacc_EEGNet_epochs_20_filtered_sub_7.npy
# Loading epoched data...
# Reading /content/drive/MyDrive/MEG/Maxwell Filtered Data/Combined Run data/Sub_3_combined_epochs-epo.fif ...
#     Read a total of 4 projection items:
#         ECG-planar--0.200-0.400-PCA-01 (1 x 204) active
#         ECG-axial--0.200-0.400-PCA-01 (1 x 102) active
#         EOG-planar--0.200-0.200-PCA-01 (1 x 204) active
#         EOG-axial--0.200-0.200-PCA-01 (1 x 102) active
#     Found the data of interest:
#         t =    2000.00 ...    6000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 400 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 4)
# 4 projection items activated
# Epoched data successfully loaded <EpochsFIF |  400 events (all good), 2 – 6 s, baseline -0.2 – 0 s (baseline period was cropped after baseline correction), ~1.98 GB, data loaded,
#  'hand_imagery': 100
#  'feet_imagery': 100
#  'subtraction_imagery': 100
#  'word_imagery': 100>

# %%
event_id = {'hand_imagery': 4, 'feet_imagery': 8, 'subtraction_imagery': 16, 'word_imagery': 32}
event_pairs = [('hand_imagery', 'word_imagery'), ('hand_imagery', 'subtraction_imagery'),
               ('feet_imagery', 'word_imagery'), ('feet_imagery', 'subtraction_imagery')]

nsub = 1

# Motor vs Mental activity
event_pair_1 = [hands_vs_word]
event_pair_2 = [hands_vs_sub]
event_pair_3 = [feet_vs_word]
event_pair_4 = [feet_vs_sub]
event_pair_5 = [hands_vs_feet]
event_pair_6 = [word_vs_sub]

event_pair = [hands_vs_word, hands_vs_sub, feet_vs_word, feet_vs_sub, hands_vs_feet, word_vs_sub]

# %%
# Choosing kernel length values
kl_values = [8,16, 32, 64, 128]

# Controlling dropout values
d_values = [0.1, 0.2, 0.6]

# Initialize the DataFrame to store the results
results_df = pd.DataFrame(columns=['Event Pair', 'Best kl', 'Best d', 'Best AUC Score', 'Best F1 Score'])

# List of event pairs and their corresponding selection functions
event_pairs = [
    ('hands_vs_word', hands_vs_word),
    ('hands_vs_sub', hands_vs_sub),
    ('feet_vs_word', feet_vs_word)
]

# event_pairs = [
#     ('feet_vs_sub', feet_vs_sub),
#     ('hands_vs_feet', hands_vs_feet),
#     ('word_vs_sub', word_vs_sub)
# ]

# Iterate over the event pairs
for event_pair_name, event_pair_function in event_pairs:
    print(f"Training for event pair: {event_pair_name}")

    # Preprocess the data for the current event pair
    epochs_data_selected = preprocess_data(event_pair_function, epoched_data)

    # Extract data and labels
    X = epochs_data_selected.get_data()
    y = epochs_data_selected.events[:, -1]

    # Map the event codes to integer labels starting from 0
    unique_events = np.unique(y)
    event_to_label = {event: idx for idx, event in enumerate(unique_events)}
    y_labels = np.array([event_to_label[event] for event in y])

    # One-hot encode the labels
    y_one_hot = to_categorical(y_labels, num_classes=2)

    # Split the data into training and testing sets (95% for training, 5% for testing)
    X_train, X_test, y_train, y_test = train_test_split(X, y_one_hot, test_size=0.05, random_state=42, stratify=y_one_hot)

    # Normalize the data using min-max scaling
    X_train = min_max_scaler(X_train)
    X_test = min_max_scaler(X_test)

    # Reshape the data to match EEGNet input format
    X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2], 1)
    X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)

    # Update the nb_classes parameter in the EEGNet function
    nb_classes = y_train.shape[1]

    # Initialize variables to store the highest AUC score and corresponding kl, d values for the current event pair
    highest_auc_score = 0
    best_kl = None
    best_d = None

    # Iterate over the kl and d values
    for kl in kl_values:
        for d in d_values:
            print()
            print(f"Current kl: {kl}")
            print(f"Current d: {d}")
            print()

            # Configure the EEGNet model
            model = EEGNet(nb_classes=nb_classes, Chans=X_train.shape[1], Samples=X_train.shape[2], dropoutRate=d, kernLength=kl)

            # Compile the model
            model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

            # Set a valid path for model checkpoints
            checkpointer = ModelCheckpoint(filepath='/tmp/checkpoint.h5', verbose=1, save_best_only=True)

            # Class weights
            class_weights = {0: 1, 1: 1}

            # Fit the model to the training data
            history = model.fit(X_train, y_train, batch_size=16, epochs=n_epochs, verbose=2,
                                validation_split=0.2, callbacks=[checkpointer, EarlyStopping(patience=5)],
                                class_weight=class_weights)

            # Evaluate the model on the test data
            y_pred = model.predict(X_test)
            auc_score = roc_auc_score(y_test, y_pred)
            f1_score_val = f1_score(y_test.argmax(axis=1), y_pred.argmax(axis=1), average='macro')

            # Print the AUC and F1 scores
            print('AUC Accuracy Score:', auc_score)
            print('F1 Score:', f1_score_val)

            # Check if the current AUC score is higher than the highest recorded score for the current event pair
            if auc_score > highest_auc_score:
                highest_auc_score = auc_score
                best_kl = kl
                best_d = d

            # Reset the Keras session to clear the model
            K.clear_session()

            print()
            print('=' * 100)
            print('=' * 100)
            print()

    # Append the best parameters and scores for the current event pair to the results DataFrame
    results_df = results_df.append({'Event Pair': event_pair_name, 'Best kl': best_kl, 'Best d': best_d,
                                    'Best AUC Score': highest_auc_score, 'Best F1 Score': f1_score_val},
                                   ignore_index=True)

# Print the results DataFrame
print(results_df)
# Out:
# Training for event pair: hands_vs_word
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | ECG-axial--0.200-0.400-PCA-01, active : True, n_channels : 102, exp. var : 89.40%>
# Removing projector <Projection | EOG-axial--0.200-0.200-PCA-01, active : True, n_channels : 102, exp. var : 53.88%>
#
# Current kl: 8
# Current d: 0.1
#
# Epoch 1/20
#
# Epoch 1: val_loss improved from inf to 0.68935, saving model to /tmp/checkpoint.h5
# 10/10 - 12s - loss: 0.6876 - accuracy: 0.5066 - val_loss: 0.6894 - val_accuracy: 0.6579 - 12s/epoch - 1s/step
# Epoch 2/20
#
# Epoch 2: val_loss improved from 0.68935 to 0.68458, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.5503 - accuracy: 0.7237 - val_loss: 0.6846 - val_accuracy: 0.6579 - 993ms/epoch - 99ms/step
# Epoch 3/20
#
# Epoch 3: val_loss improved from 0.68458 to 0.67047, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.4216 - accuracy: 0.8487 - val_loss: 0.6705 - val_accuracy: 0.6579 - 986ms/epoch - 99ms/step
# Epoch 4/20
#
# Epoch 4: val_loss improved from 0.67047 to 0.65654, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.3167 - accuracy: 0.9013 - val_loss: 0.6565 - val_accuracy: 0.6579 - 1s/epoch - 127ms/step
# Epoch 5/20
#
# Epoch 5: val_loss improved from 0.65654 to 0.64633, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2897 - accuracy: 0.9079 - val_loss: 0.6463 - val_accuracy: 0.6579 - 974ms/epoch - 97ms/step
# Epoch 6/20
#
# Epoch 6: val_loss improved from 0.64633 to 0.63993, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2286 - accuracy: 0.9474 - val_loss: 0.6399 - val_accuracy: 0.6579 - 934ms/epoch - 93ms/step
# Epoch 7/20
#
# Epoch 7: val_loss improved from 0.63993 to 0.63817, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1923 - accuracy: 0.9605 - val_loss: 0.6382 - val_accuracy: 0.6579 - 950ms/epoch - 95ms/step
# Epoch 8/20
#
# Epoch 8: val_loss did not improve from 0.63817
# 10/10 - 1s - loss: 0.1615 - accuracy: 0.9803 - val_loss: 0.6435 - val_accuracy: 0.6579 - 963ms/epoch - 96ms/step
# Epoch 9/20
#
# Epoch 9: val_loss did not improve from 0.63817
# 10/10 - 1s - loss: 0.1425 - accuracy: 0.9868 - val_loss: 0.6550 - val_accuracy: 0.6579 - 932ms/epoch - 93ms/step
# Epoch 10/20
#
# Epoch 10: val_loss did not improve from 0.63817
# 10/10 - 1s - loss: 0.1234 - accuracy: 0.9803 - val_loss: 0.6710 - val_accuracy: 0.6579 - 887ms/epoch - 89ms/step
# Epoch 11/20
#
# Epoch 11: val_loss did not improve from 0.63817
# 10/10 - 1s - loss: 0.1041 - accuracy: 0.9868 - val_loss: 0.6934 - val_accuracy: 0.6579 - 916ms/epoch - 92ms/step
# Epoch 12/20
#
# Epoch 12: val_loss did not improve from 0.63817
# 10/10 - 1s - loss: 0.1035 - accuracy: 0.9868 - val_loss: 0.7248 - val_accuracy: 0.6579 - 996ms/epoch - 100ms/step
# 1/1 [==============================] - 1s 505ms/step
# AUC Accuracy Score: 0.76
# F1 Score: 0.3333333333333333
#
# ====================================================================================================
# ====================================================================================================
#
#
# Current kl: 8
# Current d: 0.2
#
# Epoch 1/20
#
# Epoch 1: val_loss improved from inf to 0.69508, saving model to /tmp/checkpoint.h5
# 10/10 - 5s - loss: 0.6742 - accuracy: 0.5921 - val_loss: 0.6951 - val_accuracy: 0.3421 - 5s/epoch - 478ms/step
# Epoch 2/20
#
# Epoch 2: val_loss did not improve from 0.69508
# 10/10 - 1s - loss: 0.5598 - accuracy: 0.7895 - val_loss: 0.6964 - val_accuracy: 0.3421 - 806ms/epoch - 81ms/step
# Epoch 3/20
#
# Epoch 3: val_loss did not improve from 0.69508
# 10/10 - 1s - loss: 0.4469 - accuracy: 0.9145 - val_loss: 0.6978 - val_accuracy: 0.3421 - 791ms/epoch - 79ms/step
# Epoch 4/20
#
# Epoch 4: val_loss did not improve from 0.69508
# 10/10 - 1s - loss: 0.3774 - accuracy: 0.8750 - val_loss: 0.6962 - val_accuracy: 0.3684 - 796ms/epoch - 80ms/step
# Epoch 5/20
#
# Epoch 5: val_loss improved from 0.69508 to 0.69108, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2957 - accuracy: 0.9079 - val_loss: 0.6911 - val_accuracy: 0.6053 - 831ms/epoch - 83ms/step
# Epoch 6/20
#
# Epoch 6: val_loss improved from 0.69108 to 0.68761, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2315 - accuracy: 0.9539 - val_loss: 0.6876 - val_accuracy: 0.6842 - 959ms/epoch - 96ms/step
# Epoch 7/20
#
# Epoch 7: val_loss did not improve from 0.68761
# 10/10 - 1s - loss: 0.2308 - accuracy: 0.9408 - val_loss: 0.6891 - val_accuracy: 0.6842 - 853ms/epoch - 85ms/step
# Epoch 8/20
#
# Epoch 8: val_loss improved from 0.68761 to 0.67914, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1809 - accuracy: 0.9803 - val_loss: 0.6791 - val_accuracy: 0.6579 - 916ms/epoch - 92ms/step
# Epoch 9/20
#
# Epoch 9: val_loss improved from 0.67914 to 0.66999, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1698 - accuracy: 0.9671 - val_loss: 0.6700 - val_accuracy: 0.6579 - 932ms/epoch - 93ms/step
# Epoch 10/20
#
# Epoch 10: val_loss improved from 0.66999 to 0.66946, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1466 - accuracy: 0.9803 - val_loss: 0.6695 - val_accuracy: 0.6579 - 898ms/epoch - 90ms/step
# Epoch 11/20
#
# Epoch 11: val_loss improved from 0.66946 to 0.66773, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1421 - accuracy: 0.9803 - val_loss: 0.6677 - val_accuracy: 0.6842 - 841ms/epoch - 84ms/step
# Epoch 12/20
#
# Epoch 12: val_loss improved from 0.66773 to 0.65684, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1317 - accuracy: 0.9868 - val_loss: 0.6568 - val_accuracy: 0.6579 - 832ms/epoch - 83ms/step
# Epoch 13/20
#
# Epoch 13: val_loss did not improve from 0.65684
# 10/10 - 1s - loss: 0.1126 - accuracy: 0.9868 - val_loss: 0.6581 - val_accuracy: 0.6842 - 787ms/epoch - 79ms/step
# Epoch 14/20
#
# Epoch 14: val_loss improved from 0.65684 to 0.64856, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.0779 - accuracy: 1.0000 - val_loss: 0.6486 - val_accuracy: 0.6579 - 847ms/epoch - 85ms/step
# Epoch 15/20
#
# Epoch 15: val_loss improved from 0.64856 to 0.63978, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.0917 - accuracy: 0.9934 - val_loss: 0.6398 - val_accuracy: 0.6579 - 831ms/epoch - 83ms/step
# Epoch 16/20
#
# Epoch 16: val_loss improved from 0.63978 to 0.63581, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.0727 - accuracy: 1.0000 - val_loss: 0.6358 - val_accuracy: 0.6579 - 880ms/epoch - 88ms/step
# Epoch 17/20
#
# Epoch 17: val_loss improved from 0.63581 to 0.62834, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.0895 - accuracy: 0.9803 - val_loss: 0.6283 - val_accuracy: 0.6842 - 837ms/epoch - 84ms/step
# Epoch 18/20
#
# Epoch 18: val_loss did not improve from 0.62834
# 10/10 - 1s - loss: 0.0930 - accuracy: 0.9803 - val_loss: 0.6347 - val_accuracy: 0.6842 - 796ms/epoch - 80ms/step
# Epoch 19/20
#
# Epoch 19: val_loss did not improve from 0.62834
# 10/10 - 1s - loss: 0.0662 - accuracy: 1.0000 - val_loss: 0.6326 - val_accuracy: 0.7105 - 792ms/epoch - 79ms/step
# Epoch 20/20
#
# Epoch 20: val_loss improved from 0.62834 to 0.62573, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.0732 - accuracy: 0.9934 - val_loss: 0.6257 - val_accuracy: 0.7105 - 831ms/epoch - 83ms/step
# 1/1 [==============================] - 0s 97ms/step
# AUC Accuracy Score: 0.88
# F1 Score: 0.7916666666666665
#
# ====================================================================================================
# ====================================================================================================
#
#
# Current kl: 8
# Current d: 0.6
#
# Epoch 1/20
#
# Epoch 1: val_loss improved from inf to 0.69536, saving model to /tmp/checkpoint.h5
# 10/10 - 4s - loss: 0.7184 - accuracy: 0.5263 - val_loss: 0.6954 - val_accuracy: 0.3421 - 4s/epoch - 448ms/step
# Epoch 2/20
#
# Epoch 2: val_loss improved from 0.69536 to 0.69521, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.6313 - accuracy: 0.6842 - val_loss: 0.6952 - val_accuracy: 0.3421 - 828ms/epoch - 83ms/step
# Epoch 3/20
#
# Epoch 3: val_loss improved from 0.69521 to 0.69399, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.5905 - accuracy: 0.7303 - val_loss: 0.6940 - val_accuracy: 0.4211 - 843ms/epoch - 84ms/step
# Epoch 4/20
#
# Epoch 4: val_loss did not improve from 0.69399
# 10/10 - 1s - loss: 0.5249 - accuracy: 0.7763 - val_loss: 0.6950 - val_accuracy: 0.3947 - 800ms/epoch - 80ms/step
# Epoch 5/20
#
# Epoch 5: val_loss improved from 0.69399 to 0.69122, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.4358 - accuracy: 0.8421 - val_loss: 0.6912 - val_accuracy: 0.5789 - 837ms/epoch - 84ms/step
# Epoch 6/20
#
# Epoch 6: val_loss improved from 0.69122 to 0.68471, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.3962 - accuracy: 0.8684 - val_loss: 0.6847 - val_accuracy: 0.6316 - 846ms/epoch - 85ms/step
# Epoch 7/20
#
# Epoch 7: val_loss improved from 0.68471 to 0.67210, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.3343 - accuracy: 0.8816 - val_loss: 0.6721 - val_accuracy: 0.6053 - 850ms/epoch - 85ms/step
# Epoch 8/20
#
# Epoch 8: val_loss improved from 0.67210 to 0.66032, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.3127 - accuracy: 0.8750 - val_loss: 0.6603 - val_accuracy: 0.6579 - 825ms/epoch - 82ms/step
# Epoch 9/20
#
# Epoch 9: val_loss improved from 0.66032 to 0.64779, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2882 - accuracy: 0.9079 - val_loss: 0.6478 - val_accuracy: 0.6579 - 825ms/epoch - 83ms/step
# Epoch 10/20
#
# Epoch 10: val_loss improved from 0.64779 to 0.63507, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2798 - accuracy: 0.8882 - val_loss: 0.6351 - val_accuracy: 0.6579 - 840ms/epoch - 84ms/step
# Epoch 11/20
#
# Epoch 11: val_loss improved from 0.63507 to 0.62490, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2460 - accuracy: 0.9408 - val_loss: 0.6249 - val_accuracy: 0.6579 - 832ms/epoch - 83ms/step
# Epoch 12/20
#
# Epoch 12: val_loss did not improve from 0.62490
# 10/10 - 1s - loss: 0.2167 - accuracy: 0.9276 - val_loss: 0.6312 - val_accuracy: 0.6579 - 831ms/epoch - 83ms/step
# Epoch 13/20
#
# Epoch 13: val_loss did not improve from 0.62490
# 10/10 - 1s - loss: 0.1875 - accuracy: 0.9342 - val_loss: 0.6429 - val_accuracy: 0.6579 - 994ms/epoch - 99ms/step
# Epoch 14/20
#
# Epoch 14: val_loss did not improve from 0.62490
# 10/10 - 1s - loss: 0.1594 - accuracy: 0.9671 - val_loss: 0.6647 - val_accuracy: 0.6579 - 843ms/epoch - 84ms/step
# Epoch 15/20
#
# Epoch 15: val_loss did not improve from 0.62490
# 10/10 - 1s - loss: 0.1518 - accuracy: 0.9605 - val_loss: 0.6838 - val_accuracy: 0.6579 - 864ms/epoch - 86ms/step
# Epoch 16/20
#
# Epoch 16: val_loss did not improve from 0.62490
# 10/10 - 1s - loss: 0.1576 - accuracy: 0.9737 - val_loss: 0.7155 - val_accuracy: 0.6579 - 832ms/epoch - 83ms/step
# 1/1 [==============================] - 0s 100ms/step
# AUC Accuracy Score: 0.72
# F1 Score: 0.3333333333333333
#
# ====================================================================================================
# ====================================================================================================
#
#
# Current kl: 16
# Current d: 0.1
#
# Epoch 1/20
#
# Epoch 1: val_loss improved from inf to 0.69529, saving model to /tmp/checkpoint.h5
# 10/10 - 4s - loss: 0.6736 - accuracy: 0.6053 - val_loss: 0.6953 - val_accuracy: 0.3421 - 4s/epoch - 404ms/step
# Epoch 2/20
#
# Epoch 2: val_loss did not improve from 0.69529
# 10/10 - 1s - loss: 0.5078 - accuracy: 0.7763 - val_loss: 0.6982 - val_accuracy: 0.3421 - 889ms/epoch - 89ms/step
# Epoch 3/20
#
# Epoch 3: val_loss did not improve from 0.69529
# 10/10 - 1s - loss: 0.3828 - accuracy: 0.9013 - val_loss: 0.7007 - val_accuracy: 0.3421 - 796ms/epoch - 80ms/step
# Epoch 4/20
#
# Epoch 4: val_loss did not improve from 0.69529
# 10/10 - 1s - loss: 0.3098 - accuracy: 0.9145 - val_loss: 0.6975 - val_accuracy: 0.3684 - 807ms/epoch - 81ms/step
# Epoch 5/20
#
# Epoch 5: val_loss improved from 0.69529 to 0.68983, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2511 - accuracy: 0.9474 - val_loss: 0.6898 - val_accuracy: 0.5789 - 932ms/epoch - 93ms/step
# Epoch 6/20
#
# Epoch 6: val_loss improved from 0.68983 to 0.68284, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1965 - accuracy: 0.9671 - val_loss: 0.6828 - val_accuracy: 0.6053 - 845ms/epoch - 84ms/step
# Epoch 7/20
#
# Epoch 7: val_loss improved from 0.68284 to 0.67164, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1501 - accuracy: 0.9803 - val_loss: 0.6716 - val_accuracy: 0.6579 - 963ms/epoch - 96ms/step
# Epoch 8/20
#
# Epoch 8: val_loss improved from 0.67164 to 0.66136, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1232 - accuracy: 1.0000 - val_loss: 0.6614 - val_accuracy: 0.6579 - 927ms/epoch - 93ms/step
# Epoch 9/20
#
# Epoch 9: val_loss improved from 0.66136 to 0.64310, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1486 - accuracy: 0.9605 - val_loss: 0.6431 - val_accuracy: 0.6579 - 921ms/epoch - 92ms/step
# Epoch 10/20
#
# Epoch 10: val_loss improved from 0.64310 to 0.64303, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1097 - accuracy: 0.9803 - val_loss: 0.6430 - val_accuracy: 0.6579 - 908ms/epoch - 91ms/step
# Epoch 11/20
#
# Epoch 11: val_loss improved from 0.64303 to 0.62913, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1087 - accuracy: 0.9868 - val_loss: 0.6291 - val_accuracy: 0.6579 - 897ms/epoch - 90ms/step
# Epoch 12/20
#
# Epoch 12: val_loss did not improve from 0.62913
# 10/10 - 1s - loss: 0.0969 - accuracy: 0.9868 - val_loss: 0.6293 - val_accuracy: 0.6579 - 806ms/epoch - 81ms/step
# Epoch 13/20
#
# Epoch 13: val_loss improved from 0.62913 to 0.62552, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.0787 - accuracy: 1.0000 - val_loss: 0.6255 - val_accuracy: 0.6579 - 850ms/epoch - 85ms/step
# Epoch 14/20
#
# Epoch 14: val_loss improved from 0.62552 to 0.62074, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.0774 - accuracy: 0.9868 - val_loss: 0.6207 - val_accuracy: 0.6579 - 854ms/epoch - 85ms/step
# Epoch 15/20
#
# Epoch 15: val_loss did not improve from 0.62074
# 10/10 - 1s - loss: 0.0679 - accuracy: 0.9934 - val_loss: 0.6258 - val_accuracy: 0.6579 - 805ms/epoch - 81ms/step
# Epoch 16/20
#
# Epoch 16: val_loss did not improve from 0.62074
# 10/10 - 1s - loss: 0.0457 - accuracy: 1.0000 - val_loss: 0.6383 - val_accuracy: 0.6579 - 803ms/epoch - 80ms/step
# Epoch 17/20
#
# Epoch 17: val_loss did not improve from 0.62074
# 10/10 - 1s - loss: 0.0809 - accuracy: 0.9868 - val_loss: 0.6545 - val_accuracy: 0.6579 - 805ms/epoch - 80ms/step
# Epoch 18/20
#
# Epoch 18: val_loss did not improve from 0.62074
# 10/10 - 1s - loss: 0.0572 - accuracy: 0.9934 - val_loss: 0.6690 - val_accuracy: 0.6579 - 808ms/epoch - 81ms/step
# Epoch 19/20
#
# Epoch 19: val_loss did not improve from 0.62074
# 10/10 - 1s - loss: 0.0472 - accuracy: 1.0000 - val_loss: 0.6769 - val_accuracy: 0.6579 - 813ms/epoch - 81ms/step
# 1/1 [==============================] - 0s 213ms/step
# AUC Accuracy Score: 0.84
# F1 Score: 0.3333333333333333
#
# ====================================================================================================
# ====================================================================================================
#
#
# Current kl: 16
# Current d: 0.2
#
# Epoch 1/20
#
# Epoch 1: val_loss improved from inf to 0.69454, saving model to /tmp/checkpoint.h5
# 10/10 - 5s - loss: 0.6843 - accuracy: 0.5263 - val_loss: 0.6945 - val_accuracy: 0.3421 - 5s/epoch - 525ms/step
# Epoch 2/20
#
# Epoch 2: val_loss improved from 0.69454 to 0.69302, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.5640 - accuracy: 0.8289 - val_loss: 0.6930 - val_accuracy: 0.6053 - 858ms/epoch - 86ms/step
# Epoch 3/20
#
# Epoch 3: val_loss did not improve from 0.69302
# 10/10 - 1s - loss: 0.4575 - accuracy: 0.8947 - val_loss: 0.6932 - val_accuracy: 0.5000 - 807ms/epoch - 81ms/step
# Epoch 4/20
#
# Epoch 4: val_loss improved from 0.69302 to 0.68764, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.3750 - accuracy: 0.9145 - val_loss: 0.6876 - val_accuracy: 0.6316 - 851ms/epoch - 85ms/step
# Epoch 5/20
#
# Epoch 5: val_loss improved from 0.68764 to 0.68279, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.3166 - accuracy: 0.9276 - val_loss: 0.6828 - val_accuracy: 0.6579 - 850ms/epoch - 85ms/step
# Epoch 6/20
#
# Epoch 6: val_loss improved from 0.68279 to 0.67407, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2658 - accuracy: 0.9474 - val_loss: 0.6741 - val_accuracy: 0.6579 - 839ms/epoch - 84ms/step
# Epoch 7/20
#
# Epoch 7: val_loss improved from 0.67407 to 0.66444, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2277 - accuracy: 0.9737 - val_loss: 0.6644 - val_accuracy: 0.6579 - 865ms/epoch - 86ms/step
# Epoch 8/20
#
# Epoch 8: val_loss improved from 0.66444 to 0.65026, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1968 - accuracy: 0.9671 - val_loss: 0.6503 - val_accuracy: 0.6579 - 860ms/epoch - 86ms/step
# Epoch 9/20
#
# Epoch 9: val_loss improved from 0.65026 to 0.63746, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1761 - accuracy: 0.9868 - val_loss: 0.6375 - val_accuracy: 0.6579 - 840ms/epoch - 84ms/step
# Epoch 10/20
#
# Epoch 10: val_loss improved from 0.63746 to 0.62608, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1508 - accuracy: 0.9868 - val_loss: 0.6261 - val_accuracy: 0.6579 - 867ms/epoch - 87ms/step
# Epoch 11/20
#
# Epoch 11: val_loss improved from 0.62608 to 0.62302, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1291 - accuracy: 0.9934 - val_loss: 0.6230 - val_accuracy: 0.6579 - 837ms/epoch - 84ms/step
# Epoch 12/20
#
# Epoch 12: val_loss did not improve from 0.62302
# 10/10 - 1s - loss: 0.1232 - accuracy: 0.9868 - val_loss: 0.6256 - val_accuracy: 0.6579 - 908ms/epoch - 91ms/step
# Epoch 13/20
#
# Epoch 13: val_loss did not improve from 0.62302
# 10/10 - 1s - loss: 0.1084 - accuracy: 0.9868 - val_loss: 0.6329 - val_accuracy: 0.6579 - 877ms/epoch - 88ms/step
# Epoch 14/20
#
# Epoch 14: val_loss did not improve from 0.62302
# 10/10 - 1s - loss: 0.0954 - accuracy: 1.0000 - val_loss: 0.6449 - val_accuracy: 0.6579 - 859ms/epoch - 86ms/step
# Epoch 15/20
#
# Epoch 15: val_loss did not improve from 0.62302
# 10/10 - 1s - loss: 0.0806 - accuracy: 1.0000 - val_loss: 0.6665 - val_accuracy: 0.6579 - 855ms/epoch - 86ms/step
# Epoch 16/20
#
# Epoch 16: val_loss did not improve from 0.62302
# 10/10 - 1s - loss: 0.0825 - accuracy: 1.0000 - val_loss: 0.6929 - val_accuracy: 0.6579 - 867ms/epoch - 87ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7dfad1680670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 119ms/step
# AUC Accuracy Score: 0.8800000000000001
# F1 Score: 0.3333333333333333
#
# ====================================================================================================
# ====================================================================================================
#
#
# Current kl: 16
# Current d: 0.6
#
# Epoch 1/20
#
# Epoch 1: val_loss improved from inf to 0.69506, saving model to /tmp/checkpoint.h5
# 10/10 - 3s - loss: 0.7148 - accuracy: 0.5197 - val_loss: 0.6951 - val_accuracy: 0.3421 - 3s/epoch - 346ms/step
# Epoch 2/20
#
# Epoch 2: val_loss did not improve from 0.69506
# 10/10 - 1s - loss: 0.6418 - accuracy: 0.6382 - val_loss: 0.6970 - val_accuracy: 0.3421 - 795ms/epoch - 80ms/step
# Epoch 3/20
#
# Epoch 3: val_loss did not improve from 0.69506
# 10/10 - 1s - loss: 0.5922 - accuracy: 0.7500 - val_loss: 0.6983 - val_accuracy: 0.3421 - 815ms/epoch - 82ms/step
# Epoch 4/20
#
# Epoch 4: val_loss did not improve from 0.69506
# 10/10 - 1s - loss: 0.5455 - accuracy: 0.8158 - val_loss: 0.7027 - val_accuracy: 0.3421 - 883ms/epoch - 88ms/step
# Epoch 5/20
#
# Epoch 5: val_loss did not improve from 0.69506
# 10/10 - 1s - loss: 0.4895 - accuracy: 0.8026 - val_loss: 0.7084 - val_accuracy: 0.3421 - 861ms/epoch - 86ms/step
# Epoch 6/20
#
# Epoch 6: val_loss did not improve from 0.69506
# 10/10 - 1s - loss: 0.4135 - accuracy: 0.8421 - val_loss: 0.7107 - val_accuracy: 0.3421 - 846ms/epoch - 85ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7dfad05c7400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 145ms/step
# AUC Accuracy Score: 0.76
# F1 Score: 0.3333333333333333
#
# ====================================================================================================
# ====================================================================================================
#
#
# Current kl: 32
# Current d: 0.1
#
# Epoch 1/20
#
# Epoch 1: val_loss improved from inf to 0.69151, saving model to /tmp/checkpoint.h5
# 10/10 - 4s - loss: 0.6997 - accuracy: 0.5461 - val_loss: 0.6915 - val_accuracy: 0.6579 - 4s/epoch - 421ms/step
# Epoch 2/20
#
# Epoch 2: val_loss improved from 0.69151 to 0.68811, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.5582 - accuracy: 0.7500 - val_loss: 0.6881 - val_accuracy: 0.6579 - 879ms/epoch - 88ms/step
# Epoch 3/20
#
# Epoch 3: val_loss improved from 0.68811 to 0.68120, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.4682 - accuracy: 0.8618 - val_loss: 0.6812 - val_accuracy: 0.6579 - 866ms/epoch - 87ms/step
# Epoch 4/20
#
# Epoch 4: val_loss improved from 0.68120 to 0.66938, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.3715 - accuracy: 0.9276 - val_loss: 0.6694 - val_accuracy: 0.6579 - 872ms/epoch - 87ms/step
# Epoch 5/20
#
# Epoch 5: val_loss improved from 0.66938 to 0.65283, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.3039 - accuracy: 0.9342 - val_loss: 0.6528 - val_accuracy: 0.6579 - 880ms/epoch - 88ms/step
# Epoch 6/20
#
# Epoch 6: val_loss improved from 0.65283 to 0.63770, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2264 - accuracy: 0.9803 - val_loss: 0.6377 - val_accuracy: 0.6579 - 871ms/epoch - 87ms/step
# Epoch 7/20
#
# Epoch 7: val_loss improved from 0.63770 to 0.63335, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1796 - accuracy: 0.9868 - val_loss: 0.6333 - val_accuracy: 0.6579 - 878ms/epoch - 88ms/step
# Epoch 8/20
#
# Epoch 8: val_loss did not improve from 0.63335
# 10/10 - 1s - loss: 0.1672 - accuracy: 0.9605 - val_loss: 0.6454 - val_accuracy: 0.6579 - 900ms/epoch - 90ms/step
# Epoch 9/20
#
# Epoch 9: val_loss did not improve from 0.63335
# 10/10 - 1s - loss: 0.1353 - accuracy: 0.9868 - val_loss: 0.6670 - val_accuracy: 0.6579 - 872ms/epoch - 87ms/step
# Epoch 10/20
#
# Epoch 10: val_loss did not improve from 0.63335
# 10/10 - 1s - loss: 0.1244 - accuracy: 0.9737 - val_loss: 0.6954 - val_accuracy: 0.6579 - 898ms/epoch - 90ms/step
# Epoch 11/20
#
# Epoch 11: val_loss did not improve from 0.63335
# 10/10 - 1s - loss: 0.1120 - accuracy: 0.9868 - val_loss: 0.7218 - val_accuracy: 0.6579 - 879ms/epoch - 88ms/step
# Epoch 12/20
#
# Epoch 12: val_loss did not improve from 0.63335
# 10/10 - 1s - loss: 0.0851 - accuracy: 0.9934 - val_loss: 0.7647 - val_accuracy: 0.6579 - 897ms/epoch - 90ms/step
# 1/1 [==============================] - 0s 238ms/step
# AUC Accuracy Score: 0.76
# F1 Score: 0.3333333333333333
#
# ====================================================================================================
# ====================================================================================================
#
#
# Current kl: 32
# Current d: 0.2
#
# Epoch 1/20
#
# Epoch 1: val_loss improved from inf to 0.69439, saving model to /tmp/checkpoint.h5
# 10/10 - 3s - loss: 0.6887 - accuracy: 0.5461 - val_loss: 0.6944 - val_accuracy: 0.3421 - 3s/epoch - 343ms/step
# Epoch 2/20
#
# Epoch 2: val_loss did not improve from 0.69439
# 10/10 - 1s - loss: 0.5412 - accuracy: 0.7895 - val_loss: 0.6968 - val_accuracy: 0.3421 - 825ms/epoch - 83ms/step
# Epoch 3/20
#
# Epoch 3: val_loss did not improve from 0.69439
# 10/10 - 1s - loss: 0.4456 - accuracy: 0.8487 - val_loss: 0.7017 - val_accuracy: 0.3421 - 818ms/epoch - 82ms/step
# Epoch 4/20
#
# Epoch 4: val_loss did not improve from 0.69439
# 10/10 - 1s - loss: 0.3579 - accuracy: 0.9211 - val_loss: 0.7080 - val_accuracy: 0.3421 - 822ms/epoch - 82ms/step
# Epoch 5/20
#
# Epoch 5: val_loss did not improve from 0.69439
# 10/10 - 1s - loss: 0.3069 - accuracy: 0.9276 - val_loss: 0.7225 - val_accuracy: 0.3421 - 834ms/epoch - 83ms/step
# Epoch 6/20
#
# Epoch 6: val_loss did not improve from 0.69439
# 10/10 - 1s - loss: 0.2827 - accuracy: 0.9342 - val_loss: 0.7283 - val_accuracy: 0.3421 - 839ms/epoch - 84ms/step
# 1/1 [==============================] - 0s 111ms/step
# AUC Accuracy Score: 0.6799999999999999
# F1 Score: 0.3333333333333333
#
# ====================================================================================================
# ====================================================================================================
#
#
# Current kl: 32
# Current d: 0.6
#
# Epoch 1/20
#
# Epoch 1: val_loss improved from inf to 0.69513, saving model to /tmp/checkpoint.h5
# 10/10 - 5s - loss: 0.7041 - accuracy: 0.5658 - val_loss: 0.6951 - val_accuracy: 0.3421 - 5s/epoch - 464ms/step
# Epoch 2/20
#
# Epoch 2: val_loss did not improve from 0.69513
# 10/10 - 1s - loss: 0.6628 - accuracy: 0.6053 - val_loss: 0.6956 - val_accuracy: 0.3421 - 847ms/epoch - 85ms/step
# Epoch 3/20
#
# Epoch 3: val_loss did not improve from 0.69513
# 10/10 - 1s - loss: 0.5883 - accuracy: 0.6974 - val_loss: 0.6966 - val_accuracy: 0.3421 - 832ms/epoch - 83ms/step
# Epoch 4/20
#
# Epoch 4: val_loss did not improve from 0.69513
# 10/10 - 1s - loss: 0.5300 - accuracy: 0.7829 - val_loss: 0.6988 - val_accuracy: 0.3421 - 828ms/epoch - 83ms/step
# Epoch 5/20
#
# Epoch 5: val_loss did not improve from 0.69513
# 10/10 - 1s - loss: 0.4513 - accuracy: 0.8026 - val_loss: 0.6964 - val_accuracy: 0.4211 - 842ms/epoch - 84ms/step
# Epoch 6/20
#
# Epoch 6: val_loss did not improve from 0.69513
# 10/10 - 1s - loss: 0.4030 - accuracy: 0.8355 - val_loss: 0.6959 - val_accuracy: 0.4211 - 905ms/epoch - 91ms/step
# 1/1 [==============================] - 0s 100ms/step
# AUC Accuracy Score: 0.8
# F1 Score: 0.6969696969696968
#
# ====================================================================================================
# ====================================================================================================
#
#
# Current kl: 64
# Current d: 0.1
#
# Epoch 1/20
#
# Epoch 1: val_loss improved from inf to 0.69277, saving model to /tmp/checkpoint.h5
# 10/10 - 4s - loss: 0.6960 - accuracy: 0.5066 - val_loss: 0.6928 - val_accuracy: 0.6579 - 4s/epoch - 431ms/step
# Epoch 2/20
#
# Epoch 2: val_loss improved from 0.69277 to 0.68535, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.5217 - accuracy: 0.8158 - val_loss: 0.6854 - val_accuracy: 0.6579 - 1s/epoch - 102ms/step
# Epoch 3/20
#
# Epoch 3: val_loss improved from 0.68535 to 0.67441, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.3552 - accuracy: 0.9276 - val_loss: 0.6744 - val_accuracy: 0.6579 - 964ms/epoch - 96ms/step
# Epoch 4/20
#
# Epoch 4: val_loss improved from 0.67441 to 0.65862, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2748 - accuracy: 0.9605 - val_loss: 0.6586 - val_accuracy: 0.6579 - 1s/epoch - 104ms/step
# Epoch 5/20
#
# Epoch 5: val_loss improved from 0.65862 to 0.64713, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1871 - accuracy: 0.9737 - val_loss: 0.6471 - val_accuracy: 0.6579 - 1s/epoch - 104ms/step
# Epoch 6/20
#
# Epoch 6: val_loss improved from 0.64713 to 0.63859, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1497 - accuracy: 0.9737 - val_loss: 0.6386 - val_accuracy: 0.6579 - 934ms/epoch - 93ms/step
# Epoch 7/20
#
# Epoch 7: val_loss improved from 0.63859 to 0.63303, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1484 - accuracy: 0.9671 - val_loss: 0.6330 - val_accuracy: 0.6579 - 980ms/epoch - 98ms/step
# Epoch 8/20
#
# Epoch 8: val_loss improved from 0.63303 to 0.63187, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1261 - accuracy: 0.9803 - val_loss: 0.6319 - val_accuracy: 0.6579 - 914ms/epoch - 91ms/step
# Epoch 9/20
#
# Epoch 9: val_loss improved from 0.63187 to 0.62520, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.0906 - accuracy: 0.9934 - val_loss: 0.6252 - val_accuracy: 0.6579 - 901ms/epoch - 90ms/step
# Epoch 10/20
#
# Epoch 10: val_loss improved from 0.62520 to 0.62363, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.0781 - accuracy: 0.9934 - val_loss: 0.6236 - val_accuracy: 0.6579 - 904ms/epoch - 90ms/step
# Epoch 11/20
#
# Epoch 11: val_loss did not improve from 0.62363
# 10/10 - 1s - loss: 0.0783 - accuracy: 0.9934 - val_loss: 0.6237 - val_accuracy: 0.6579 - 867ms/epoch - 87ms/step
# Epoch 12/20
#
# Epoch 12: val_loss improved from 0.62363 to 0.61909, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.0647 - accuracy: 1.0000 - val_loss: 0.6191 - val_accuracy: 0.6579 - 920ms/epoch - 92ms/step
# Epoch 13/20
#
# Epoch 13: val_loss improved from 0.61909 to 0.61782, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.0473 - accuracy: 1.0000 - val_loss: 0.6178 - val_accuracy: 0.6579 - 920ms/epoch - 92ms/step
# Epoch 14/20
#
# Epoch 14: val_loss improved from 0.61782 to 0.61522, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.0500 - accuracy: 1.0000 - val_loss: 0.6152 - val_accuracy: 0.6579 - 908ms/epoch - 91ms/step
# Epoch 15/20
#
# Epoch 15: val_loss improved from 0.61522 to 0.61230, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.0499 - accuracy: 0.9934 - val_loss: 0.6123 - val_accuracy: 0.6579 - 897ms/epoch - 90ms/step
# Epoch 16/20
#
# Epoch 16: val_loss improved from 0.61230 to 0.60343, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.0448 - accuracy: 0.9934 - val_loss: 0.6034 - val_accuracy: 0.6579 - 914ms/epoch - 91ms/step
# Epoch 17/20
#
# Epoch 17: val_loss improved from 0.60343 to 0.59585, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.0426 - accuracy: 1.0000 - val_loss: 0.5958 - val_accuracy: 0.6579 - 945ms/epoch - 95ms/step
# Epoch 18/20
#
# Epoch 18: val_loss improved from 0.59585 to 0.58834, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.0316 - accuracy: 1.0000 - val_loss: 0.5883 - val_accuracy: 0.6579 - 954ms/epoch - 95ms/step
# Epoch 19/20
#
# Epoch 19: val_loss improved from 0.58834 to 0.58789, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.0398 - accuracy: 1.0000 - val_loss: 0.5879 - val_accuracy: 0.6579 - 1s/epoch - 105ms/step
# Epoch 20/20
#
# Epoch 20: val_loss did not improve from 0.58789
# 10/10 - 1s - loss: 0.0260 - accuracy: 1.0000 - val_loss: 0.5892 - val_accuracy: 0.6579 - 992ms/epoch - 99ms/step
# 1/1 [==============================] - 0s 273ms/step
# AUC Accuracy Score: 0.6799999999999999
# F1 Score: 0.6703296703296704
#
# ====================================================================================================
# ====================================================================================================
#
#
# Current kl: 64
# Current d: 0.2
#
# Epoch 1/20
#
# Epoch 1: val_loss improved from inf to 0.69388, saving model to /tmp/checkpoint.h5
# 10/10 - 4s - loss: 0.7001 - accuracy: 0.5592 - val_loss: 0.6939 - val_accuracy: 0.3158 - 4s/epoch - 350ms/step
# Epoch 2/20
#
# Epoch 2: val_loss did not improve from 0.69388
# 10/10 - 1s - loss: 0.5813 - accuracy: 0.7829 - val_loss: 0.6948 - val_accuracy: 0.3421 - 944ms/epoch - 94ms/step
# Epoch 3/20
#
# Epoch 3: val_loss did not improve from 0.69388
# 10/10 - 1s - loss: 0.4788 - accuracy: 0.8289 - val_loss: 0.6946 - val_accuracy: 0.4211 - 871ms/epoch - 87ms/step
# Epoch 4/20
#
# Epoch 4: val_loss improved from 0.69388 to 0.68981, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.3938 - accuracy: 0.8553 - val_loss: 0.6898 - val_accuracy: 0.5263 - 986ms/epoch - 99ms/step
# Epoch 5/20
#
# Epoch 5: val_loss improved from 0.68981 to 0.68240, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.3027 - accuracy: 0.9342 - val_loss: 0.6824 - val_accuracy: 0.6316 - 904ms/epoch - 90ms/step
# Epoch 6/20
#
# Epoch 6: val_loss improved from 0.68240 to 0.66719, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2636 - accuracy: 0.9408 - val_loss: 0.6672 - val_accuracy: 0.6579 - 900ms/epoch - 90ms/step
# Epoch 7/20
#
# Epoch 7: val_loss improved from 0.66719 to 0.65346, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1889 - accuracy: 0.9803 - val_loss: 0.6535 - val_accuracy: 0.6579 - 907ms/epoch - 91ms/step
# Epoch 8/20
#
# Epoch 8: val_loss improved from 0.65346 to 0.64060, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1653 - accuracy: 0.9737 - val_loss: 0.6406 - val_accuracy: 0.6579 - 1s/epoch - 102ms/step
# Epoch 9/20
#
# Epoch 9: val_loss improved from 0.64060 to 0.63544, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1477 - accuracy: 0.9737 - val_loss: 0.6354 - val_accuracy: 0.6579 - 989ms/epoch - 99ms/step
# Epoch 10/20
#
# Epoch 10: val_loss improved from 0.63544 to 0.63270, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1178 - accuracy: 0.9868 - val_loss: 0.6327 - val_accuracy: 0.6579 - 1s/epoch - 105ms/step
# Epoch 11/20
#
# Epoch 11: val_loss did not improve from 0.63270
# 10/10 - 1s - loss: 0.0934 - accuracy: 0.9934 - val_loss: 0.6377 - val_accuracy: 0.6579 - 995ms/epoch - 99ms/step
# Epoch 12/20
#
# Epoch 12: val_loss did not improve from 0.63270
# 10/10 - 1s - loss: 0.0911 - accuracy: 0.9934 - val_loss: 0.6514 - val_accuracy: 0.6579 - 880ms/epoch - 88ms/step
# Epoch 13/20
#
# Epoch 13: val_loss did not improve from 0.63270
# 10/10 - 1s - loss: 0.0730 - accuracy: 1.0000 - val_loss: 0.6651 - val_accuracy: 0.6579 - 866ms/epoch - 87ms/step
# Epoch 14/20
#
# Epoch 14: val_loss did not improve from 0.63270
# 10/10 - 1s - loss: 0.0706 - accuracy: 0.9934 - val_loss: 0.6840 - val_accuracy: 0.6579 - 863ms/epoch - 86ms/step
# Epoch 15/20
#
# Epoch 15: val_loss did not improve from 0.63270
# 10/10 - 1s - loss: 0.0783 - accuracy: 0.9803 - val_loss: 0.7085 - val_accuracy: 0.6579 - 868ms/epoch - 87ms/step
# 1/1 [==============================] - 0s 96ms/step
# AUC Accuracy Score: 0.76
# F1 Score: 0.3333333333333333
#
# ====================================================================================================
# ====================================================================================================
#
#
# Current kl: 64
# Current d: 0.6
#
# Epoch 1/20
#
# Epoch 1: val_loss improved from inf to 0.69354, saving model to /tmp/checkpoint.h5
# 10/10 - 4s - loss: 0.7286 - accuracy: 0.4605 - val_loss: 0.6935 - val_accuracy: 0.3947 - 4s/epoch - 414ms/step
# Epoch 2/20
#
# Epoch 2: val_loss did not improve from 0.69354
# 10/10 - 1s - loss: 0.6656 - accuracy: 0.6382 - val_loss: 0.6955 - val_accuracy: 0.3421 - 871ms/epoch - 87ms/step
# Epoch 3/20
#
# Epoch 3: val_loss did not improve from 0.69354
# 10/10 - 1s - loss: 0.6254 - accuracy: 0.6711 - val_loss: 0.6987 - val_accuracy: 0.3421 - 887ms/epoch - 89ms/step
# Epoch 4/20
#
# Epoch 4: val_loss did not improve from 0.69354
# 10/10 - 1s - loss: 0.5716 - accuracy: 0.7829 - val_loss: 0.7026 - val_accuracy: 0.3421 - 908ms/epoch - 91ms/step
# Epoch 5/20
#
# Epoch 5: val_loss did not improve from 0.69354
# 10/10 - 1s - loss: 0.5071 - accuracy: 0.8026 - val_loss: 0.7088 - val_accuracy: 0.3421 - 1s/epoch - 101ms/step
# Epoch 6/20
#
# Epoch 6: val_loss did not improve from 0.69354
# 10/10 - 1s - loss: 0.4650 - accuracy: 0.8092 - val_loss: 0.7164 - val_accuracy: 0.3421 - 937ms/epoch - 94ms/step
# 1/1 [==============================] - 0s 156ms/step
# AUC Accuracy Score: 0.76
# F1 Score: 0.3333333333333333
#
# ====================================================================================================
# ====================================================================================================
#
#
# Current kl: 128
# Current d: 0.1
#
# Epoch 1/20
#
# Epoch 1: val_loss improved from inf to 0.69428, saving model to /tmp/checkpoint.h5
# 10/10 - 5s - loss: 0.6941 - accuracy: 0.5526 - val_loss: 0.6943 - val_accuracy: 0.3421 - 5s/epoch - 492ms/step
# Epoch 2/20
#
# Epoch 2: val_loss did not improve from 0.69428
# 10/10 - 1s - loss: 0.5764 - accuracy: 0.7632 - val_loss: 0.6952 - val_accuracy: 0.3421 - 966ms/epoch - 97ms/step
# Epoch 3/20
#
# Epoch 3: val_loss did not improve from 0.69428
# 10/10 - 1s - loss: 0.4612 - accuracy: 0.9013 - val_loss: 0.6959 - val_accuracy: 0.3421 - 1s/epoch - 103ms/step
# Epoch 4/20
#
# Epoch 4: val_loss did not improve from 0.69428
# 10/10 - 1s - loss: 0.3630 - accuracy: 0.8947 - val_loss: 0.6954 - val_accuracy: 0.4474 - 971ms/epoch - 97ms/step
# Epoch 5/20
#
# Epoch 5: val_loss improved from 0.69428 to 0.69168, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2868 - accuracy: 0.9474 - val_loss: 0.6917 - val_accuracy: 0.5526 - 1s/epoch - 102ms/step
# Epoch 6/20
#
# Epoch 6: val_loss improved from 0.69168 to 0.68332, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2045 - accuracy: 0.9803 - val_loss: 0.6833 - val_accuracy: 0.6579 - 1s/epoch - 110ms/step
# Epoch 7/20
#
# Epoch 7: val_loss improved from 0.68332 to 0.66814, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1658 - accuracy: 0.9868 - val_loss: 0.6681 - val_accuracy: 0.7105 - 1s/epoch - 106ms/step
# Epoch 8/20
#
# Epoch 8: val_loss improved from 0.66814 to 0.64951, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1396 - accuracy: 0.9934 - val_loss: 0.6495 - val_accuracy: 0.6579 - 1s/epoch - 105ms/step
# Epoch 9/20
#
# Epoch 9: val_loss improved from 0.64951 to 0.63157, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1075 - accuracy: 0.9803 - val_loss: 0.6316 - val_accuracy: 0.6579 - 1s/epoch - 115ms/step
# Epoch 10/20
#
# Epoch 10: val_loss improved from 0.63157 to 0.62035, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.0894 - accuracy: 1.0000 - val_loss: 0.6204 - val_accuracy: 0.6579 - 1s/epoch - 102ms/step
# Epoch 11/20
#
# Epoch 11: val_loss improved from 0.62035 to 0.61073, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.0772 - accuracy: 1.0000 - val_loss: 0.6107 - val_accuracy: 0.6579 - 1s/epoch - 108ms/step
# Epoch 12/20
#
# Epoch 12: val_loss improved from 0.61073 to 0.61050, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.0746 - accuracy: 1.0000 - val_loss: 0.6105 - val_accuracy: 0.6579 - 1s/epoch - 108ms/step
# Epoch 13/20
#
# Epoch 13: val_loss did not improve from 0.61050
# 10/10 - 1s - loss: 0.0679 - accuracy: 1.0000 - val_loss: 0.6113 - val_accuracy: 0.6579 - 968ms/epoch - 97ms/step
# Epoch 14/20
#
# Epoch 14: val_loss did not improve from 0.61050
# 10/10 - 1s - loss: 0.0566 - accuracy: 1.0000 - val_loss: 0.6205 - val_accuracy: 0.6579 - 1s/epoch - 103ms/step
# Epoch 15/20
#
# Epoch 15: val_loss did not improve from 0.61050
# 10/10 - 1s - loss: 0.0424 - accuracy: 1.0000 - val_loss: 0.6472 - val_accuracy: 0.6579 - 961ms/epoch - 96ms/step
# Epoch 16/20
#
# Epoch 16: val_loss did not improve from 0.61050
# 10/10 - 1s - loss: 0.0353 - accuracy: 1.0000 - val_loss: 0.6694 - val_accuracy: 0.6579 - 1s/epoch - 103ms/step
# Epoch 17/20
#
# Epoch 17: val_loss did not improve from 0.61050
# 10/10 - 1s - loss: 0.0318 - accuracy: 1.0000 - val_loss: 0.6985 - val_accuracy: 0.6579 - 962ms/epoch - 96ms/step
# 1/1 [==============================] - 0s 320ms/step
# AUC Accuracy Score: 0.8400000000000001
# F1 Score: 0.3333333333333333
#
# ====================================================================================================
# ====================================================================================================
#
#
# Current kl: 128
# Current d: 0.2
#
# Epoch 1/20
#
# Epoch 1: val_loss improved from inf to 0.69457, saving model to /tmp/checkpoint.h5
# 10/10 - 5s - loss: 0.6982 - accuracy: 0.5592 - val_loss: 0.6946 - val_accuracy: 0.3421 - 5s/epoch - 463ms/step
# Epoch 2/20
#
# Epoch 2: val_loss did not improve from 0.69457
# 10/10 - 1s - loss: 0.5436 - accuracy: 0.7434 - val_loss: 0.6988 - val_accuracy: 0.3421 - 985ms/epoch - 98ms/step
# Epoch 3/20
#
# Epoch 3: val_loss did not improve from 0.69457
# 10/10 - 1s - loss: 0.4362 - accuracy: 0.8487 - val_loss: 0.7060 - val_accuracy: 0.3421 - 960ms/epoch - 96ms/step
# Epoch 4/20
#
# Epoch 4: val_loss did not improve from 0.69457
# 10/10 - 1s - loss: 0.3672 - accuracy: 0.9013 - val_loss: 0.7145 - val_accuracy: 0.3421 - 956ms/epoch - 96ms/step
# Epoch 5/20
#
# Epoch 5: val_loss did not improve from 0.69457
# 10/10 - 1s - loss: 0.2798 - accuracy: 0.9539 - val_loss: 0.7212 - val_accuracy: 0.3421 - 1s/epoch - 104ms/step
# Epoch 6/20
#
# Epoch 6: val_loss did not improve from 0.69457
# 10/10 - 1s - loss: 0.2392 - accuracy: 0.9605 - val_loss: 0.7321 - val_accuracy: 0.3421 - 961ms/epoch - 96ms/step
# 1/1 [==============================] - 0s 99ms/step
# AUC Accuracy Score: 0.6399999999999999
# F1 Score: 0.3333333333333333
#
# ====================================================================================================
# ====================================================================================================
#
#
# Current kl: 128
# Current d: 0.6
#
# Epoch 1/20
#
# Epoch 1: val_loss improved from inf to 0.69359, saving model to /tmp/checkpoint.h5
# 10/10 - 4s - loss: 0.7250 - accuracy: 0.4868 - val_loss: 0.6936 - val_accuracy: 0.4474 - 4s/epoch - 383ms/step
# Epoch 2/20
#
# Epoch 2: val_loss did not improve from 0.69359
# 10/10 - 1s - loss: 0.6319 - accuracy: 0.6579 - val_loss: 0.6936 - val_accuracy: 0.4737 - 1s/epoch - 109ms/step
# Epoch 3/20
#
# Epoch 3: val_loss did not improve from 0.69359
# 10/10 - 1s - loss: 0.5926 - accuracy: 0.7039 - val_loss: 0.6942 - val_accuracy: 0.4211 - 1s/epoch - 101ms/step
# Epoch 4/20
#
# Epoch 4: val_loss improved from 0.69359 to 0.68762, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.4972 - accuracy: 0.7566 - val_loss: 0.6876 - val_accuracy: 0.6053 - 1s/epoch - 106ms/step
# Epoch 5/20
#
# Epoch 5: val_loss improved from 0.68762 to 0.67457, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.4259 - accuracy: 0.8421 - val_loss: 0.6746 - val_accuracy: 0.6316 - 1s/epoch - 101ms/step
# Epoch 6/20
#
# Epoch 6: val_loss improved from 0.67457 to 0.66042, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.3621 - accuracy: 0.8882 - val_loss: 0.6604 - val_accuracy: 0.6579 - 1s/epoch - 108ms/step
# Epoch 7/20
#
# Epoch 7: val_loss improved from 0.66042 to 0.64344, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2719 - accuracy: 0.9211 - val_loss: 0.6434 - val_accuracy: 0.6579 - 1s/epoch - 101ms/step
# Epoch 8/20
#
# Epoch 8: val_loss improved from 0.64344 to 0.62845, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2446 - accuracy: 0.9342 - val_loss: 0.6285 - val_accuracy: 0.6579 - 1s/epoch - 107ms/step
# Epoch 9/20
#
# Epoch 9: val_loss improved from 0.62845 to 0.62407, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2007 - accuracy: 0.9276 - val_loss: 0.6241 - val_accuracy: 0.6579 - 1s/epoch - 101ms/step
# Epoch 10/20
#
# Epoch 10: val_loss did not improve from 0.62407
# 10/10 - 1s - loss: 0.1701 - accuracy: 0.9737 - val_loss: 0.6332 - val_accuracy: 0.6579 - 1s/epoch - 104ms/step
# Epoch 11/20
#
# Epoch 11: val_loss did not improve from 0.62407
# 10/10 - 1s - loss: 0.1536 - accuracy: 0.9737 - val_loss: 0.6344 - val_accuracy: 0.6579 - 1s/epoch - 104ms/step
# Epoch 12/20
#
# Epoch 12: val_loss did not improve from 0.62407
# 10/10 - 1s - loss: 0.1499 - accuracy: 0.9605 - val_loss: 0.6474 - val_accuracy: 0.6579 - 954ms/epoch - 95ms/step
# Epoch 13/20
#
# Epoch 13: val_loss did not improve from 0.62407
# 10/10 - 1s - loss: 0.1492 - accuracy: 0.9539 - val_loss: 0.6815 - val_accuracy: 0.6579 - 964ms/epoch - 96ms/step
# Epoch 14/20
#
# Epoch 14: val_loss did not improve from 0.62407
# 10/10 - 1s - loss: 0.1114 - accuracy: 0.9868 - val_loss: 0.7075 - val_accuracy: 0.6579 - 989ms/epoch - 99ms/step
# 1/1 [==============================] - 0s 98ms/step
# AUC Accuracy Score: 0.6799999999999999
# F1 Score: 0.3333333333333333
#
# ====================================================================================================
# ====================================================================================================
#
# Training for event pair: hands_vs_sub
# <ipython-input-6-474665ea5f23>:107: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'Event Pair': event_pair_name, 'Best kl': best_kl, 'Best d': best_d,
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | ECG-axial--0.200-0.400-PCA-01, active : True, n_channels : 102, exp. var : 89.40%>
# Removing projector <Projection | EOG-axial--0.200-0.200-PCA-01, active : True, n_channels : 102, exp. var : 53.88%>
#
# Current kl: 8
# Current d: 0.1
#
# Epoch 1/20
#
# Epoch 1: val_loss improved from inf to 0.69397, saving model to /tmp/checkpoint.h5
# 10/10 - 3s - loss: 0.7092 - accuracy: 0.4737 - val_loss: 0.6940 - val_accuracy: 0.3684 - 3s/epoch - 343ms/step
# Epoch 2/20
#
# Epoch 2: val_loss did not improve from 0.69397
# 10/10 - 1s - loss: 0.5600 - accuracy: 0.7763 - val_loss: 0.6978 - val_accuracy: 0.3421 - 807ms/epoch - 81ms/step
# Epoch 3/20
#
# Epoch 3: val_loss did not improve from 0.69397
# 10/10 - 1s - loss: 0.4829 - accuracy: 0.7895 - val_loss: 0.7024 - val_accuracy: 0.3421 - 800ms/epoch - 80ms/step
# Epoch 4/20
#
# Epoch 4: val_loss did not improve from 0.69397
# 10/10 - 1s - loss: 0.4145 - accuracy: 0.8487 - val_loss: 0.7075 - val_accuracy: 0.3421 - 845ms/epoch - 85ms/step
# Epoch 5/20
#
# Epoch 5: val_loss did not improve from 0.69397
# 10/10 - 1s - loss: 0.3315 - accuracy: 0.9145 - val_loss: 0.7150 - val_accuracy: 0.3421 - 839ms/epoch - 84ms/step
# Epoch 6/20
#
# Epoch 6: val_loss did not improve from 0.69397
# 10/10 - 1s - loss: 0.2762 - accuracy: 0.9474 - val_loss: 0.7252 - val_accuracy: 0.3421 - 869ms/epoch - 87ms/step
# 1/1 [==============================] - 0s 94ms/step
# AUC Accuracy Score: 0.56
# F1 Score: 0.3333333333333333
#
# ====================================================================================================
# ====================================================================================================
#
#
# Current kl: 8
# Current d: 0.2
#
# Epoch 1/20
#
# Epoch 1: val_loss improved from inf to 0.69009, saving model to /tmp/checkpoint.h5
# 10/10 - 3s - loss: 0.7340 - accuracy: 0.5263 - val_loss: 0.6901 - val_accuracy: 0.6579 - 3s/epoch - 341ms/step
# Epoch 2/20
#
# Epoch 2: val_loss improved from 0.69009 to 0.68936, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.5661 - accuracy: 0.7434 - val_loss: 0.6894 - val_accuracy: 0.6579 - 841ms/epoch - 84ms/step
# Epoch 3/20
#
# Epoch 3: val_loss improved from 0.68936 to 0.68808, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.4615 - accuracy: 0.8158 - val_loss: 0.6881 - val_accuracy: 0.6316 - 840ms/epoch - 84ms/step
# Epoch 4/20
#
# Epoch 4: val_loss improved from 0.68808 to 0.68437, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.3825 - accuracy: 0.8882 - val_loss: 0.6844 - val_accuracy: 0.6579 - 856ms/epoch - 86ms/step
# Epoch 5/20
#
# Epoch 5: val_loss improved from 0.68437 to 0.68247, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.3101 - accuracy: 0.9276 - val_loss: 0.6825 - val_accuracy: 0.6579 - 884ms/epoch - 88ms/step
# Epoch 6/20
#
# Epoch 6: val_loss improved from 0.68247 to 0.67745, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2996 - accuracy: 0.9211 - val_loss: 0.6774 - val_accuracy: 0.6579 - 904ms/epoch - 90ms/step
# Epoch 7/20
#
# Epoch 7: val_loss improved from 0.67745 to 0.67199, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2506 - accuracy: 0.9737 - val_loss: 0.6720 - val_accuracy: 0.6579 - 923ms/epoch - 92ms/step
# Epoch 8/20
#
# Epoch 8: val_loss improved from 0.67199 to 0.66357, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1843 - accuracy: 0.9671 - val_loss: 0.6636 - val_accuracy: 0.6579 - 885ms/epoch - 88ms/step
# Epoch 9/20
#
# Epoch 9: val_loss improved from 0.66357 to 0.66194, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1607 - accuracy: 0.9737 - val_loss: 0.6619 - val_accuracy: 0.6579 - 978ms/epoch - 98ms/step
# Epoch 10/20
#
# ...
# Epoch 12/20
#
# Epoch 12: val_loss did not improve from 0.63374
# 10/10 - 1s - loss: 0.1828 - accuracy: 0.9934 - val_loss: 0.6380 - val_accuracy: 0.6579 - 1s/epoch - 100ms/step
# Epoch 13/20
#
# Epoch 13: val_loss did not improve from 0.63374
# 10/10 - 1s - loss: 0.1484 - accuracy: 1.0000 - val_loss: 0.6593 - val_accuracy: 0.6579 - 938ms/epoch - 94ms/step
# Epoch 14/20
#
# Epoch 14: val_loss did not improve from 0.63374
# 10/10 - 1s - loss: 0.1445 - accuracy: 0.9803 - val_loss: 0.6935 - val_accuracy: 0.6579 - 1s/epoch - 101ms/step
# Epoch 15/20
#
# Epoch 15: val_loss did not improve from 0.63374
# 10/10 - 1s - loss: 0.1182 - accuracy: 0.9934 - val_loss: 0.7305 - val_accuracy: 0.6579 - 992ms/epoch - 99ms/step
# Epoch 16/20
#
# Epoch 16: val_loss did not improve from 0.63374
# 10/10 - 1s - loss: 0.0922 - accuracy: 1.0000 - val_loss: 0.8025 - val_accuracy: 0.6579 - 882ms/epoch - 88ms/step
# 1/1 [==============================] - 0s 108ms/step
# AUC Accuracy Score: 0.84
# F1 Score: 0.3333333333333333
#
# ====================================================================================================
# ====================================================================================================
#
#
# Current kl: 64
# Current d: 0.6
#
# Epoch 1/20
#
# Epoch 1: val_loss improved from inf to 0.69225, saving model to /tmp/checkpoint.h5
# 10/10 - 4s - loss: 0.6872 - accuracy: 0.5132 - val_loss: 0.6922 - val_accuracy: 0.6579 - 4s/epoch - 370ms/step
# Epoch 2/20
#
# Epoch 2: val_loss improved from 0.69225 to 0.69065, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.6343 - accuracy: 0.6842 - val_loss: 0.6907 - val_accuracy: 0.6579 - 924ms/epoch - 92ms/step
# Epoch 3/20
#
# Epoch 3: val_loss improved from 0.69065 to 0.68736, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.6009 - accuracy: 0.7237 - val_loss: 0.6874 - val_accuracy: 0.6579 - 919ms/epoch - 92ms/step
# Epoch 4/20
#
# Epoch 4: val_loss improved from 0.68736 to 0.68127, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.5349 - accuracy: 0.8092 - val_loss: 0.6813 - val_accuracy: 0.6579 - 930ms/epoch - 93ms/step
# Epoch 5/20
#
# Epoch 5: val_loss improved from 0.68127 to 0.67304, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.4771 - accuracy: 0.8092 - val_loss: 0.6730 - val_accuracy: 0.6579 - 1s/epoch - 101ms/step
# Epoch 6/20
#
# Epoch 6: val_loss improved from 0.67304 to 0.66598, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.4441 - accuracy: 0.8158 - val_loss: 0.6660 - val_accuracy: 0.6579 - 1s/epoch - 106ms/step
# Epoch 7/20
#
# Epoch 7: val_loss improved from 0.66598 to 0.65551, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.3870 - accuracy: 0.8618 - val_loss: 0.6555 - val_accuracy: 0.6579 - 1s/epoch - 101ms/step
# Epoch 8/20
#
# Epoch 8: val_loss improved from 0.65551 to 0.64440, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.3746 - accuracy: 0.8816 - val_loss: 0.6444 - val_accuracy: 0.6579 - 1s/epoch - 101ms/step
# Epoch 9/20
#
# Epoch 9: val_loss improved from 0.64440 to 0.64233, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.3533 - accuracy: 0.8684 - val_loss: 0.6423 - val_accuracy: 0.6579 - 1s/epoch - 108ms/step
# Epoch 10/20
#
# Epoch 10: val_loss did not improve from 0.64233
# 10/10 - 1s - loss: 0.2999 - accuracy: 0.8882 - val_loss: 0.6428 - val_accuracy: 0.6579 - 885ms/epoch - 89ms/step
# Epoch 11/20
#
# Epoch 11: val_loss did not improve from 0.64233
# 10/10 - 1s - loss: 0.2597 - accuracy: 0.9211 - val_loss: 0.6529 - val_accuracy: 0.6579 - 873ms/epoch - 87ms/step
# Epoch 12/20
#
# Epoch 12: val_loss did not improve from 0.64233
# 10/10 - 1s - loss: 0.2456 - accuracy: 0.9276 - val_loss: 0.6753 - val_accuracy: 0.6579 - 887ms/epoch - 89ms/step
# Epoch 13/20
#
# Epoch 13: val_loss did not improve from 0.64233
# 10/10 - 1s - loss: 0.2249 - accuracy: 0.9474 - val_loss: 0.6953 - val_accuracy: 0.6579 - 872ms/epoch - 87ms/step
# Epoch 14/20
#
# Epoch 14: val_loss did not improve from 0.64233
# 10/10 - 1s - loss: 0.2051 - accuracy: 0.9605 - val_loss: 0.7367 - val_accuracy: 0.6579 - 886ms/epoch - 89ms/step
# 1/1 [==============================] - 0s 108ms/step
# AUC Accuracy Score: 0.52
# F1 Score: 0.3333333333333333
#
# ====================================================================================================
# ====================================================================================================
#
#
# Current kl: 128
# Current d: 0.1
#
# Epoch 1/20
#
# Epoch 1: val_loss improved from inf to 0.69151, saving model to /tmp/checkpoint.h5
# 10/10 - 5s - loss: 0.7039 - accuracy: 0.5263 - val_loss: 0.6915 - val_accuracy: 0.6579 - 5s/epoch - 482ms/step
# Epoch 2/20
#
# Epoch 2: val_loss improved from 0.69151 to 0.68759, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.5844 - accuracy: 0.7039 - val_loss: 0.6876 - val_accuracy: 0.6579 - 1s/epoch - 109ms/step
# Epoch 3/20
#
# Epoch 3: val_loss improved from 0.68759 to 0.68423, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.4930 - accuracy: 0.8224 - val_loss: 0.6842 - val_accuracy: 0.6579 - 1s/epoch - 109ms/step
# Epoch 4/20
#
# Epoch 4: val_loss improved from 0.68423 to 0.68206, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.4115 - accuracy: 0.8816 - val_loss: 0.6821 - val_accuracy: 0.6579 - 1s/epoch - 102ms/step
# Epoch 5/20
#
# Epoch 5: val_loss improved from 0.68206 to 0.67748, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.3522 - accuracy: 0.9079 - val_loss: 0.6775 - val_accuracy: 0.6579 - 1s/epoch - 109ms/step
# Epoch 6/20
#
# Epoch 6: val_loss improved from 0.67748 to 0.67252, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2979 - accuracy: 0.9539 - val_loss: 0.6725 - val_accuracy: 0.6579 - 1s/epoch - 101ms/step
# Epoch 7/20
#
# Epoch 7: val_loss improved from 0.67252 to 0.66699, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2672 - accuracy: 0.9671 - val_loss: 0.6670 - val_accuracy: 0.6579 - 1s/epoch - 110ms/step
# Epoch 8/20
#
# Epoch 8: val_loss improved from 0.66699 to 0.66093, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2155 - accuracy: 0.9803 - val_loss: 0.6609 - val_accuracy: 0.6579 - 1s/epoch - 101ms/step
# Epoch 9/20
#
# Epoch 9: val_loss improved from 0.66093 to 0.65262, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1921 - accuracy: 0.9803 - val_loss: 0.6526 - val_accuracy: 0.6579 - 1s/epoch - 112ms/step
# Epoch 10/20
#
# Epoch 10: val_loss improved from 0.65262 to 0.64448, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1836 - accuracy: 0.9803 - val_loss: 0.6445 - val_accuracy: 0.6579 - 1s/epoch - 107ms/step
# Epoch 11/20
#
# Epoch 11: val_loss improved from 0.64448 to 0.63749, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1444 - accuracy: 0.9934 - val_loss: 0.6375 - val_accuracy: 0.6579 - 1s/epoch - 115ms/step
# Epoch 12/20
#
# Epoch 12: val_loss improved from 0.63749 to 0.63473, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.1373 - accuracy: 0.9868 - val_loss: 0.6347 - val_accuracy: 0.6579 - 1s/epoch - 118ms/step
# Epoch 13/20
#
# Epoch 13: val_loss did not improve from 0.63473
# 10/10 - 1s - loss: 0.1159 - accuracy: 0.9934 - val_loss: 0.6367 - val_accuracy: 0.6579 - 1s/epoch - 107ms/step
# Epoch 14/20
#
# Epoch 14: val_loss did not improve from 0.63473
# 10/10 - 1s - loss: 0.1092 - accuracy: 0.9934 - val_loss: 0.6407 - val_accuracy: 0.6579 - 980ms/epoch - 98ms/step
# Epoch 15/20
#
# Epoch 15: val_loss did not improve from 0.63473
# 10/10 - 1s - loss: 0.0846 - accuracy: 0.9934 - val_loss: 0.6530 - val_accuracy: 0.6579 - 1s/epoch - 105ms/step
# Epoch 16/20
#
# Epoch 16: val_loss did not improve from 0.63473
# 10/10 - 1s - loss: 0.0677 - accuracy: 1.0000 - val_loss: 0.6737 - val_accuracy: 0.6579 - 970ms/epoch - 97ms/step
# Epoch 17/20
#
# Epoch 17: val_loss did not improve from 0.63473
# 10/10 - 1s - loss: 0.0673 - accuracy: 1.0000 - val_loss: 0.7055 - val_accuracy: 0.6579 - 1s/epoch - 104ms/step
# 1/1 [==============================] - 0s 103ms/step
# AUC Accuracy Score: 0.6
# F1 Score: 0.3333333333333333
#
# ====================================================================================================
# ====================================================================================================
#
#
# Current kl: 128
# Current d: 0.2
#
# Epoch 1/20
#
# Epoch 1: val_loss improved from inf to 0.69430, saving model to /tmp/checkpoint.h5
# 10/10 - 4s - loss: 0.7173 - accuracy: 0.5132 - val_loss: 0.6943 - val_accuracy: 0.3421 - 4s/epoch - 369ms/step
# Epoch 2/20
#
# Epoch 2: val_loss improved from 0.69430 to 0.69393, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.6017 - accuracy: 0.7829 - val_loss: 0.6939 - val_accuracy: 0.3947 - 1s/epoch - 105ms/step
# Epoch 3/20
#
# Epoch 3: val_loss improved from 0.69393 to 0.69090, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.5186 - accuracy: 0.8487 - val_loss: 0.6909 - val_accuracy: 0.6316 - 1s/epoch - 108ms/step
# Epoch 4/20
#
# Epoch 4: val_loss improved from 0.69090 to 0.68391, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.4471 - accuracy: 0.8947 - val_loss: 0.6839 - val_accuracy: 0.6579 - 1s/epoch - 116ms/step
# Epoch 5/20
#
# Epoch 5: val_loss improved from 0.68391 to 0.67678, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.3732 - accuracy: 0.9079 - val_loss: 0.6768 - val_accuracy: 0.6579 - 1s/epoch - 111ms/step
# Epoch 6/20
#
# Epoch 6: val_loss improved from 0.67678 to 0.66746, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.3264 - accuracy: 0.9211 - val_loss: 0.6675 - val_accuracy: 0.6579 - 1s/epoch - 104ms/step
# Epoch 7/20
#
# Epoch 7: val_loss improved from 0.66746 to 0.65603, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2990 - accuracy: 0.9342 - val_loss: 0.6560 - val_accuracy: 0.6579 - 1s/epoch - 109ms/step
# Epoch 8/20
#
# Epoch 8: val_loss improved from 0.65603 to 0.64554, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2558 - accuracy: 0.9671 - val_loss: 0.6455 - val_accuracy: 0.6579 - 1s/epoch - 103ms/step
# Epoch 9/20
#
# Epoch 9: val_loss improved from 0.64554 to 0.63873, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2090 - accuracy: 0.9934 - val_loss: 0.6387 - val_accuracy: 0.6579 - 1s/epoch - 110ms/step
# Epoch 10/20
#
# Epoch 10: val_loss did not improve from 0.63873
# 10/10 - 1s - loss: 0.1638 - accuracy: 0.9934 - val_loss: 0.6445 - val_accuracy: 0.6579 - 1s/epoch - 105ms/step
# Epoch 11/20
#
# Epoch 11: val_loss did not improve from 0.63873
# 10/10 - 1s - loss: 0.1509 - accuracy: 0.9934 - val_loss: 0.6613 - val_accuracy: 0.6579 - 976ms/epoch - 98ms/step
# Epoch 12/20
#
# Epoch 12: val_loss did not improve from 0.63873
# 10/10 - 1s - loss: 0.1206 - accuracy: 0.9934 - val_loss: 0.7056 - val_accuracy: 0.6579 - 983ms/epoch - 98ms/step
# Epoch 13/20
#
# Epoch 13: val_loss did not improve from 0.63873
# 10/10 - 1s - loss: 0.1149 - accuracy: 0.9868 - val_loss: 0.7613 - val_accuracy: 0.6579 - 971ms/epoch - 97ms/step
# Epoch 14/20
#
# Epoch 14: val_loss did not improve from 0.63873
# 10/10 - 1s - loss: 0.1154 - accuracy: 0.9803 - val_loss: 0.7979 - val_accuracy: 0.6579 - 965ms/epoch - 96ms/step
# 1/1 [==============================] - 0s 101ms/step
# AUC Accuracy Score: 0.76
# F1 Score: 0.3333333333333333
#
# ====================================================================================================
# ====================================================================================================
#
#
# Current kl: 128
# Current d: 0.6
#
# Epoch 1/20
#
# Epoch 1: val_loss improved from inf to 0.69222, saving model to /tmp/checkpoint.h5
# 10/10 - 4s - loss: 0.7470 - accuracy: 0.4737 - val_loss: 0.6922 - val_accuracy: 0.6842 - 4s/epoch - 369ms/step
# Epoch 2/20
#
# Epoch 2: val_loss improved from 0.69222 to 0.69083, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.6490 - accuracy: 0.6382 - val_loss: 0.6908 - val_accuracy: 0.6579 - 1s/epoch - 102ms/step
# Epoch 3/20
#
# Epoch 3: val_loss improved from 0.69083 to 0.68940, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.6213 - accuracy: 0.7237 - val_loss: 0.6894 - val_accuracy: 0.6316 - 1s/epoch - 108ms/step
# Epoch 4/20
#
# Epoch 4: val_loss improved from 0.68940 to 0.68602, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.5743 - accuracy: 0.7368 - val_loss: 0.6860 - val_accuracy: 0.6053 - 1s/epoch - 103ms/step
# Epoch 5/20
#
# Epoch 5: val_loss improved from 0.68602 to 0.68215, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.4962 - accuracy: 0.7829 - val_loss: 0.6822 - val_accuracy: 0.6579 - 1s/epoch - 103ms/step
# Epoch 6/20
#
# Epoch 6: val_loss improved from 0.68215 to 0.68026, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.4619 - accuracy: 0.8487 - val_loss: 0.6803 - val_accuracy: 0.6842 - 1s/epoch - 105ms/step
# Epoch 7/20
#
# Epoch 7: val_loss improved from 0.68026 to 0.67499, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.4440 - accuracy: 0.8026 - val_loss: 0.6750 - val_accuracy: 0.6579 - 1s/epoch - 108ms/step
# Epoch 8/20
#
# Epoch 8: val_loss improved from 0.67499 to 0.67031, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.4264 - accuracy: 0.8289 - val_loss: 0.6703 - val_accuracy: 0.7105 - 1s/epoch - 117ms/step
# Epoch 9/20
#
# Epoch 9: val_loss improved from 0.67031 to 0.66463, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.3779 - accuracy: 0.8816 - val_loss: 0.6646 - val_accuracy: 0.6842 - 1s/epoch - 116ms/step
# Epoch 10/20
#
# Epoch 10: val_loss improved from 0.66463 to 0.66075, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.3589 - accuracy: 0.8816 - val_loss: 0.6607 - val_accuracy: 0.6842 - 1s/epoch - 111ms/step
# Epoch 11/20
#
# Epoch 11: val_loss improved from 0.66075 to 0.65697, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.3255 - accuracy: 0.9013 - val_loss: 0.6570 - val_accuracy: 0.7105 - 1s/epoch - 101ms/step
# Epoch 12/20
#
# Epoch 12: val_loss did not improve from 0.65697
# 10/10 - 1s - loss: 0.2978 - accuracy: 0.9211 - val_loss: 0.6573 - val_accuracy: 0.7105 - 961ms/epoch - 96ms/step
# Epoch 13/20
#
# Epoch 13: val_loss improved from 0.65697 to 0.65199, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2811 - accuracy: 0.9145 - val_loss: 0.6520 - val_accuracy: 0.7105 - 1s/epoch - 110ms/step
# Epoch 14/20
#
# Epoch 14: val_loss improved from 0.65199 to 0.64716, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2775 - accuracy: 0.9342 - val_loss: 0.6472 - val_accuracy: 0.7105 - 1s/epoch - 110ms/step
# Epoch 15/20
#
# Epoch 15: val_loss improved from 0.64716 to 0.64196, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2369 - accuracy: 0.9474 - val_loss: 0.6420 - val_accuracy: 0.7368 - 1s/epoch - 102ms/step
# Epoch 16/20
#
# Epoch 16: val_loss did not improve from 0.64196
# 10/10 - 1s - loss: 0.2347 - accuracy: 0.9342 - val_loss: 0.6437 - val_accuracy: 0.6579 - 974ms/epoch - 97ms/step
# Epoch 17/20
#
# Epoch 17: val_loss improved from 0.64196 to 0.63849, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2185 - accuracy: 0.9671 - val_loss: 0.6385 - val_accuracy: 0.6053 - 1s/epoch - 101ms/step
# Epoch 18/20
#
# Epoch 18: val_loss improved from 0.63849 to 0.63453, saving model to /tmp/checkpoint.h5
# 10/10 - 1s - loss: 0.2293 - accuracy: 0.9342 - val_loss: 0.6345 - val_accuracy: 0.6579 - 1s/epoch - 109ms/step
# Epoch 19/20
#
# Epoch 19: val_loss did not improve from 0.63453
# 10/10 - 1s - loss: 0.2102 - accuracy: 0.9605 - val_loss: 0.6436 - val_accuracy: 0.6316 - 997ms/epoch - 100ms/step
# Epoch 20/20
#
# Epoch 20: val_loss did not improve from 0.63453
# 10/10 - 1s - loss: 0.1669 - accuracy: 0.9868 - val_loss: 0.6460 - val_accuracy: 0.5789 - 1s/epoch - 110ms/step
# 1/1 [==============================] - 0s 106ms/step
# AUC Accuracy Score: 0.5599999999999999
# F1 Score: 0.375
#
# ====================================================================================================
# ====================================================================================================
#
# Training for event pair: word_vs_sub
# <ipython-input-6-474665ea5f23>:107: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'Event Pair': event_pair_name, 'Best kl': best_kl, 'Best d': best_d,
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
